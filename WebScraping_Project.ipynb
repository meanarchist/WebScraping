# %% [markdown]
# <a href="https://colab.research.google.com/github/meanarchist/WebScraping/blob/main/WebScraping_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import getpass
login_url=('https://academia.srmist.edu.in/accounts/signin.ac')
timetable_url=('https://academia.srmist.edu.in/srm_university/academia-academic-services/page/My_Time_Table_2020_21_22')
cookies1=('https://academia.srmist.edu.in/oauthorize?state=https%3A%2F%2Facademia.srmist.edu.in%2F&servicename=ZohoCreator&portal=10002227248&zacode=10015051375-15444a05-1c89ac8d86522143e018451931db837a&oauthorize=true&remember=86400')
cookies2=('https://academia.srmist.edu.in/')

# %%
payload={
    'username' : input("Enter Username: "),
    'password' : getpass.getpass("Enter Password: "),
    'client_portal': True,
    'dcc': True,
    'serviceurl': "https://academia.srmist.edu.in/",
    'servicename': "ZohoCreator",
    'portal': 10002227248,
    'service_language': "en",
    'is_ajax': True,
    'grant_type': "password"
}
# Out:
# Enter Username: jt8574@srmist.edu.in
# Enter Password: ··········

# %%
from requests.sessions import session
import json
with requests.session() as s:
  session=requests.Session()
  s.get(cookies1)
  s.cookies
  s.get(cookies2)
  s.cookies
  s.post(login_url, data=payload)
  r = s.get(timetable_url)
  soup = BeautifulSoup(r.content, 'html.parser')
  print(soup.prettify())
# Out:
# <!-- $Id$ -->
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="noindex" name="robots"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport">
#    <title>
#     Academia - Academic Web Services Login
#    </title>
#    <link href="https://static.zohocdn.com/creator/app/css/defaultPortalPages.a2ce99167c462b0d410199074d39b06d.css" rel="stylesheet" type="text/css"/>
#    <script src="https://static.zohocdn.com/creator/zcs/js/jquery.586ebc8153c2550ef27f2ce2eb58b9c7.js" type="text/javascript">
#    </script>
#    <link href="https://static.zohocdn.com/creator/zcs/css/font-latonew.9eed39f534c23948c9af56aee271f0a5.css" rel="stylesheet" type="text/css"/>
#    <script src="https://static.zohocdn.com/creator/zcs/js/tp-xregexp.4e97aa1b9e2629f25170377706314afb.js" type="text/javascript">
#    </script>
# ...
